# %%
import pandas as pd

# %%
def us_new_cases_14day_moving_avg(state=None):
    df = pd.read_csv('csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv')
    if not state is None:
        df = df.loc[df['Province_State'] == state]
    df = df.drop(['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Lat', 'Long_', 'Combined_Key'], axis=1).sum().diff().fillna(value=0).rolling(14, min_periods=1).mean()
    return pd.DataFrame({'14-day avg': df})

# %%
df = us_new_cases_14day_moving_avg()
df.plot(title='USA')

# %%
state='Alabama'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Alaska'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Arkansas'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Arizona'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='California'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Colorado'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Connecticut'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='District of Columbia'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Delaware'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Florida'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Georgia'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Hawaii'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Iowa'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Idaho'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Illinois'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Indiana'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Kansas'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Kentucky'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Louisiana'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Massachusetts'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Maryland'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Maine'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Michigan'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Minnesota'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Missouri'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Mississippi'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Montana'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='North Carolina'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Nebraska'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='North Dakota'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='New Hampshire'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='New Jersey'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='New Mexico'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='New York'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Nevada'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Oklahoma'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Ohio'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Oregon'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Pennsylvania'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Rhode Island'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='South Carolina'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='South Dakota'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Tennessee'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Texas'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Utah'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Virginia'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Vermont'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Washington'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Wisconsin'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='West Virginia'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)

# %%
state='Wyoming'
df = us_new_cases_14day_moving_avg(state=state)
df.plot(title=state)
