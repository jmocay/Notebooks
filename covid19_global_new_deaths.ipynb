# %%
import pandas as pd

# %%
def global_new_deaths():
    df = pd.read_csv('csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
    df = df.drop(['Country/Region', 'Province/State', 'Lat', 'Long'], axis=1).sum(axis=0).diff().fillna(value=0).rolling(7, min_periods=1).mean()
    return df

# %%
def new_deaths_by_country(country=None):
    df = pd.read_csv('csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
    if not country is None:
        df = df.loc[df['Country/Region'] == country]
    df = df.drop(['Country/Region', 'Province/State', 'Lat', 'Long'], axis=1).sum(axis=0).diff().fillna(value=0).rolling(7, min_periods=1).mean()
    return df

# %%
df = global_new_deaths()
df.plot(title='Global Deaths')

# %%
country='Argentina'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Australia'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Belgium'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Brazil'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Canada'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Chile'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='China'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Colombia'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Croatia'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Czechia'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Denmark'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Greece'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Hungary'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='India'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='France'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Germany'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Indonesia'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Iran'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Israel'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Italy'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Japan'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Korea, South'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Mexico'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Netherlands'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='New Zealand'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Netherlands'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Norway'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Peru'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Philippines'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Poland'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Russia'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Spain'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Korea, South'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='South Africa'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Sweden'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Thailand'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Turkey'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Ukraine'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='United Kingdom'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='US'
df = new_deaths_by_country(country=country)
df.plot(title=country)

# %%
country='Vietnam'
df = new_deaths_by_country(country=country)
df.plot(title=country)
