# %%
"""
  Datasource: https://covidtracking.com/data
"""
import pandas as pd

# %%
def daily_us_hospitalization(state=None):
    df = pd.read_csv('hospitalization/all-states-history.csv',
                    usecols=['date', 'state', 'hospitalizedCurrently']).fillna(0)
    if not state is None:
        df = df.loc[df['state'] == state]
    df.sort_values('date', ascending=True, inplace=True)
    df = df.groupby(['date']).sum()
    return df

# %%
df = daily_us_hospitalization()
df.plot(title='USA')

# %%
df = daily_us_hospitalization('AL')
df.plot(title='Alabama')

# %%
df = daily_us_hospitalization('AK')
df.plot(title='Alaska')

# %%
df = daily_us_hospitalization('AR')
df.plot(title='Arkansas')

# %%
df = daily_us_hospitalization('AZ')
df.plot(title='Arizona')

# %%
df = daily_us_hospitalization('CA')
df.plot(title='California')

# %%
df = daily_us_hospitalization('CO')
df.plot(title='Colorado')

# %%
df = daily_us_hospitalization('CT')
df.plot(title='Connecticut')

# %%
df = daily_us_hospitalization('DC')
df.plot(title='Washington D.C.')

# %%
df = daily_us_hospitalization('DE')
df.plot(title='Delaware')

# %%
df = daily_us_hospitalization('FL')
df.plot(title='Florida')

# %%
df = daily_us_hospitalization('GA')
df.plot(title='Georgia')

# %%
df = daily_us_hospitalization('HI')
df.plot(title='Hawaii')

# %%
df = daily_us_hospitalization('IA')
df.plot(title='Iowa')

# %%
df = daily_us_hospitalization('ID')
df.plot(title='Idaho')

# %%
df = daily_us_hospitalization('IL')
df.plot(title='Illinois')

# %%
df = daily_us_hospitalization('IN')
df.plot(title='Indiana')

# %%
df = daily_us_hospitalization('KS')
df.plot(title='Kansas')

# %%
df = daily_us_hospitalization('KY')
df.plot(title='Kentucky')

# %%
df = daily_us_hospitalization('LA')
df.plot(title='Louisiana')

# %%
df = daily_us_hospitalization('MA')
df.plot(title='Massachusetts')

# %%
df = daily_us_hospitalization('MD')
df.plot(title='Maryland')

# %%
df = daily_us_hospitalization('ME')
df.plot(title='Maine')

# %%
df = daily_us_hospitalization('MI')
df.plot(title='Michigan')

# %%
df = daily_us_hospitalization('MN')
df.plot(title='Minnesota')

# %%
df = daily_us_hospitalization('MO')
df.plot(title='Missouri')

# %%
df = daily_us_hospitalization('MS')
df.plot(title='Mississippi')

# %%
df = daily_us_hospitalization('MT')
df.plot(title='Montana')

# %%
df = daily_us_hospitalization('NC')
df.plot(title='North Carolina')

# %%
df = daily_us_hospitalization('NE')
df.plot(title='Nebraska')

# %%
df = daily_us_hospitalization('ND')
df.plot(title='North Dakota')

# %%
df = daily_us_hospitalization('NH')
df.plot(title='New Hampshire')

# %%
df = daily_us_hospitalization('NJ')
df.plot(title='New Jersey')

# %%
df = daily_us_hospitalization('NM')
df.plot(title='New Mexico')

# %%
df = daily_us_hospitalization('NY')
df.plot(title='New York')

# %%
df = daily_us_hospitalization('NV')
df.plot(title='Nevada')

# %%
df = daily_us_hospitalization('OK')
df.plot(title='Oklahoma')

# %%
df = daily_us_hospitalization('OH')
df.plot(title='Ohio')

# %%
df = daily_us_hospitalization('OR')
df.plot(title='Oregon')

# %%
df = daily_us_hospitalization('PA')
df.plot(title='Pennsylvania')

# %%
df = daily_us_hospitalization('RI')
df.plot(title='Rhode Island')

# %%
df = daily_us_hospitalization('SC')
df.plot(title='South Carolina')

# %%
df = daily_us_hospitalization('SD')
df.plot(title='South Dakota')

# %%
df = daily_us_hospitalization('TN')
df.plot(title='Tennessee')

# %%
df = daily_us_hospitalization('TX')
df.plot(title='Texas')

# %%
df = daily_us_hospitalization('UT')
df.plot(title='Utah')

# %%
df = daily_us_hospitalization('VA')
df.plot(title='Virginia')

# %%
df = daily_us_hospitalization('VT')
df.plot(title='Vermont')

# %%
df = daily_us_hospitalization('WA')
df.plot(title='Washington')

# %%
df = daily_us_hospitalization('WI')
df.plot(title='Wisconsin')

# %%
df = daily_us_hospitalization('WV')
df.plot(title='West Virginia')

# %%
df = daily_us_hospitalization('WY')
df.plot(title='Wyoming')
