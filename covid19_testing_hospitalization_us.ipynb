# %%
import pandas as pd
from datetime import datetime
from datetime import timedelta

# %%
def datetime_to_str(dtime):
    return '{0}-{1}-{2}'.format(str(dtime.month).zfill(2), str(dtime.day).zfill(2), str(dtime.year).zfill(4))
# datetime_to_str(datetime.now())

# %%
def get_tests_data(dtime):
    exclude = [
        'Diamond Princess',
        'Grand Princess',
        'American Samoa',
        'Virgin Islands',
        'Northern Mariana Islands'
    ]
    file = '{0}.csv'.format(datetime_to_str(dtime))
    df = pd.read_csv('csse_covid_19_data/csse_covid_19_daily_reports_us/{0}'.format(file),
                     usecols=['Province_State', 'People_Tested']).fillna(0)
    df = df[~df.Province_State.isin(exclude)] # not isin
    df.rename(columns={ 'People_Tested': datetime_to_str(dtime) }, inplace=True)
    df.set_index(['Province_State'], inplace=True)
    return df

def get_daily_tests_timeseries(dtime, ndays=30):
    df = get_tests_data(dtime)
    for days in range(1, ndays+1):
        df_2 = get_tests_data(dtime - timedelta(days=days))
        df = pd.concat([df_2, df], axis=1, join='inner')
    return df

def get_daily_new_tests_timeseries(dtime, ndays=30):
    df = get_daily_tests_timeseries(dtime, ndays=ndays)
    return df.diff(axis=1).fillna(0).sum(axis=0)

def get_daily_new_tests_by_state_timeseries(dtime, ndays=30):
    df = get_daily_tests_timeseries(dtime, ndays=ndays)
    return df.diff(axis=1).fillna(0)

# %%
get_daily_tests_timeseries(datetime.now() - timedelta(days=1), ndays=10)
# Out:
#                       10-10-2020  10-11-2020  10-12-2020  10-13-2020  \
# Province_State
# Alabama                1204320.0   1210007.0   1214610.0   1221207.0
# Alaska                  499253.0    502997.0    505927.0    514789.0
# Arizona                1556015.0   1566165.0   1574200.0   1581151.0
# Arkansas               1137716.0   1146654.0   1155066.0   1162665.0
# California            15878445.0  16047004.0  16191341.0  16333717.0
# Colorado               1518454.0   1541162.0   1560179.0   1571329.0
# Connecticut            1796539.0   1796539.0   1896944.0   1910348.0
# Delaware                307645.0    310570.0    314281.0    315752.0
# District of Columbia    429099.0    436167.0    438819.0    443081.0
# Florida                5518162.0   5550531.0   5567283.0   5593424.0
# Georgia                3132559.0   3151039.0   3168126.0   3180548.0
# Guam                     54816.0     54971.0     55690.0     56368.0
# Hawaii                  447810.0    454713.0    454713.0    456118.0
# Idaho                   330962.0    333839.0    335670.0    338000.0
# Illinois               6246673.0   6310720.0   6358299.0   6414292.0
# Indiana                1474639.0   1486182.0   1495852.0   1503923.0
# Iowa                    814078.0    819460.0    822140.0    824869.0
# Kansas                  560189.0    560189.0    572081.0    572081.0
# Kentucky               1536175.0   1536175.0   1565097.0   1591005.0
# Louisiana              2450087.0   2488868.0   2492265.0   2512847.0
# Maine                   491082.0    491109.0    491138.0    514278.0
# Maryland               1719802.0   1731844.0   1742435.0   1751309.0
# Massachusetts          4670758.0   4748004.0   4815399.0   4857515.0
# Michigan               4010309.0   4010309.0   4061097.0   4099559.0
# Minnesota              2288662.0   2318810.0   2337122.0   2355124.0
# Mississippi             809293.0    809587.0    809883.0    810596.0
# Missouri               2075699.0   2075699.0   2075699.0   2075699.0
# Montana                 388649.0    390258.0    400458.0    409651.0
# Nebraska                504432.0    508921.0    511938.0    515493.0
# Nevada                  734943.0    738304.0    741168.0    743677.0
# New Hampshire           493109.0    493109.0    497910.0    508079.0
# New Jersey             3914021.0   3914772.0   3971597.0   3972585.0
# New Mexico              980053.0    989652.0    997373.0   1002906.0
# New York              11921319.0  12039573.0  12131366.0  12230436.0
# North Carolina         3350815.0   3388250.0   3417814.0   3444583.0
# North Dakota            678197.0    685711.0    691049.0    696068.0
# Ohio                   3583857.0   3623321.0   3661924.0   3698741.0
# Oklahoma               1339139.0   1339905.0   1340702.0   1373716.0
# Oregon                  736598.0    741233.0    745255.0    751277.0

    exclude = [
        'Diamond Princess',
        'Grand Princess',
        'American Samoa',
        'Virgin Islands',
        'Northern Mariana Islands'
    ]
    file = '{0}.csv'.format(datetime_to_str(dtime))
    df = pd.read_csv('csse_covid_19_data/csse_covid_19_daily_reports_us/{0}'.format(file),
                     usecols=['Province_State', 'People_Hospitalized']).fillna(0)
    df = df[~df.Province_State.isin(exclude)] # not isin
    df.rename(columns={ 'People_Hospitalized': datetime_to_str(dtime) }, inplace=True)
    df.set_index(['Province_State'], inplace=True)
    return df

def get_daily_hospitalized_timeseries(dtime, ndays=30):
    df = get_hospitalized_data(dtime)
    for days in range(1, ndays+1):
        df_2 = get_hospitalized_data(dtime - timedelta(days=days))
        df = pd.concat([df_2, df], axis=1, join='inner')
    return df

def get_daily_new_hospitalized_timeseries(dtime, ndays=30):
    df = get_daily_hospitalized_timeseries(dtime, ndays=ndays)
    return df.diff(axis=1).fillna(0).sum(axis=0)

def get_daily_new_hospitalized_by_state_timeseries(dtime, ndays=30):
    df = get_daily_hospitalized_timeseries(dtime, ndays=ndays)
    return df.diff(axis=1).fillna(0)

# %%
# get_daily_hospitalized_timeseries(datetime.now() - timedelta(days=1), ndays=10)

# %%
# get_daily_new_hospitalized_timeseries(datetime.now() - timedelta(days=1), ndays=30)

# %%
# get_daily_new_hospitalized_by_state_timeseries(datetime.now() - timedelta(days=1), ndays=10)

# %%
# dtime = datetime.now() - timedelta(days=1)
# col = datetime_to_str(dtime)
# get_daily_new_hospitalized_by_state_timeseries(dtime, ndays=14).sort_values(col, axis=0, ascending=False)[col]

# %%
def get_daily_data(dtime, col):
    exclude = [
        'Diamond Princess',
        'Grand Princess',
        'American Samoa',
        'Virgin Islands',
        'Northern Mariana Islands',
        'Puerto Rico',
    ]
    file = '{0}.csv'.format(datetime_to_str(dtime))
    df = pd.read_csv('csse_covid_19_data/csse_covid_19_daily_reports_us/{0}'.format(file),
                     usecols=['Province_State', col]).fillna(0)
    df = df[~df.Province_State.isin(exclude)] # not isin
    df.set_index(['Province_State'], inplace=True)
    return df

def get_daily_confirmed(dtime):
    conf_curr = get_daily_data(dtime, 'Confirmed')
    conf_prev = get_daily_data(dtime - timedelta(days=1), 'Confirmed')
    conf = (conf_curr - conf_prev)
    conf.rename(columns={'Confirmed': datetime_to_str(dtime)}, inplace=True)
    return conf

def get_daily_tested(dtime, lag=0):
    tstd_curr = get_daily_data(dtime - timedelta(days=lag), 'People_Tested')
    tstd_prev = get_daily_data(dtime - timedelta(days=lag+1), 'People_Tested')
    tstd = (tstd_curr - tstd_prev)
    tstd.rename(columns={'People_Tested': datetime_to_str(dtime)}, inplace=True)
    return tstd

def get_confirmed_timeseries(dtime, ndays=10):
    df = get_daily_confirmed(dtime)
    for days in range(1, ndays+1):
        df_2 = get_daily_confirmed(dtime - timedelta(days=days))
        df = pd.concat([df_2, df], axis=1, join='inner')
    return df.rolling(7, axis=1, min_periods=1).mean()

def get_tested_timeseries(dtime, lag=0, ndays=10):
    df = get_daily_tested(dtime, lag=lag)
    for days in range(1, ndays+1):
        df_2 = get_daily_tested(dtime - timedelta(days=days), lag=lag)
        df = pd.concat([df_2, df], axis=1, join='inner')
    return df.rolling(7, axis=1, min_periods=1).mean()
    
def get_pct_plus(dtime, ndays=10, lag=0):
    conf = get_confirmed_timeseries(dtime, ndays=ndays)
    tstd = get_tested_timeseries(dtime, ndays=ndays)
    return 100 * conf / tstd

# get_daily_confirmed(datetime.now() - timedelta(days=2))
# get_daily_tested(datetime.now() - timedelta(days=2))
# get_confirmed_timeseries(datetime.now() - timedelta(days=2))
# get_tested_timeseries(datetime.now() - timedelta(days=2))
# get_pct_plus(datetime.now() - timedelta(days=2), lag=1)
# get_pct_plus(datetime.now() - timedelta(days=2), lag=2)
# get_pct_plus(datetime.now() - timedelta(days=2), lag=3)
# get_pct_plus(datetime.now() - timedelta(days=2), lag
# Iowa                   56.523402   56.629197   60.549459
# Kansas                 17.120690   19.602478   20.214343
# Kentucky                5.282618    5.471963    6.776136
# Louisiana               3.588162    3.672088    3.744812
# Maine                   0.509318    0.358251    0.519892
# Maryland                0.319153    0.315338    0.321126
# Massachusetts           1.130092    1.137296    1.126356
# Michigan                4.473830    4.635974    4.587887
# Minnesota               6.187503    6.311936    6.526880
# Mississippi            16.934219   17.730473   17.776677
# Missouri                6.217282    6.463627    7.009843
# Montana                10.076818   10.177055   12.671756
# Nebraska               18.824075   19.114309   18.815756
# Nevada                 37.161098   45.965845   58.844310
# New Hampshire           1.059248    1.178481    1.547220
# New Jersey              2.685867    2.888163    2.705594
# New Mexico              6.666667    6.850030    7.167335
# New York                1.161408    1.171121    1.160186
# North Carolina          6.356546    6.256777    6.280093
# North Dakota            9.949976    9.780288   10.780181
# Ohio                    4.701292    4.807916    4.992643
# Oklahoma                8.334914    8.312698    8.633996
# Oregon                  5.190217    5.379849    5.349682
# Pennsylvania            9.149373    9.665877    9.755890
# Rhode Island            1.968021    1.812435    2.119968
# South Carolina          5.646413    5.831843    6.095480
# South Dakota           36.371367   37.187642   35.730243
# Tennessee               8.326705    8.375856    8.614241
# Texas                   8.097995    8.283389    8.202811
# Utah                   15.442412   15.122644   16.133987
# Vermont                 1.224707    1.190071    1.358432
# Virginia                5.591807    5.632420    5.715458
# Washington              3.373780    3.322173    2.392044
# West Virginia           4.152994    4.143669    4.163927
# Wisconsin              22.915350   11.992903   12.784031
# Wyoming                20.223112   21.292507   35.203967

# %%
# Assumes a 3 day lag of testing results
dtime = datetime.now() - timedelta(days=1)
col = datetime_to_str(dtime)
get_pct_plus(dtime, ndays=10, lag=0).rolling(7, axis=1, min_periods=1).mean().sort_values(col, axis=0, ascending=False)[col]
# Out:
# Province_State
# Iowa                    47.576571
# Wyoming                 42.396377
# Mississippi             41.211475
# South Dakota            36.584251
# Nevada                  32.499314
# Idaho                   26.463227
# Wisconsin               19.576041
# Nebraska                18.497232
# Kansas                  17.981335
# Alabama                 15.886588
# Utah                    15.406386
# Guam                    14.666925
# Florida                 12.501459
# Montana                 10.707119
# North Dakota             9.567916
# Pennsylvania             8.953107
# Oklahoma                 8.508726
# Arizona                  8.486516
# Tennessee                8.107847
# Arkansas                 8.057969
# Texas                    7.424269
# New Mexico               6.469302
# Georgia                  6.167524
# North Carolina           6.137744
# Minnesota                6.112512
# Missouri                 5.994198
# South Carolina           5.780186
# Virginia                 5.683592
# Kentucky                 5.656165
# Delaware                 5.621131
# Indiana                  5.599263
# Illinois                 5.307410
# Oregon                   5.301205
# Colorado                 5.195725
# Ohio                     4.582062
# Michigan                 4.416010
# Alaska                   4.321626
# West Virginia            3.930074
# Louisiana                3.406610
# Washington               2.917757
# New Jersey               2.666982
# Hawaii                   2.593700
# California               2.471904
# Rhode Island             1.927492
# Maryland                 1.731150
# Connecticut              1.657020
# New Hampshire            1.370471
# District of Columbia     1.203522
# New York                 1.146206
# Vermont                  1.140609
# Massachusetts            1.118965
# Maine                    0.479829
# Name: 10-20-2020, dtype: float64
