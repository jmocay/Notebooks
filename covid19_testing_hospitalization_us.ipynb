# %%
import pandas as pd
from datetime import datetime
from datetime import timedelta

# %%
def datetime_to_str(dtime):
    return '{0}-{1}-{2}'.format(str(dtime.month).zfill(2), str(dtime.day).zfill(2), str(dtime.year).zfill(4))
# datetime_to_str(datetime.now())

# %%
def get_tests_data(dtime):
    exclude = [
        'Diamond Princess',
        'Grand Princess',
        'American Samoa',
        'Virgin Islands',
        'Northern Mariana Islands'
    ]
    file = '{0}.csv'.format(datetime_to_str(dtime))
    df = pd.read_csv('csse_covid_19_data/csse_covid_19_daily_reports_us/{0}'.format(file),
                     usecols=['Province_State', 'People_Tested']).fillna(0)
    df = df[~df.Province_State.isin(exclude)] # not isin
    df.rename(columns={ 'People_Tested': datetime_to_str(dtime) }, inplace=True)
    df.set_index(['Province_State'], inplace=True)
    return df

def get_daily_tests_timeseries(dtime, ndays=30):
    df = get_tests_data(dtime)
    for days in range(1, ndays+1):
        df_2 = get_tests_data(dtime - timedelta(days=days))
        df = pd.concat([df_2, df], axis=1, join='inner')
    return df

def get_daily_new_tests_timeseries(dtime, ndays=30):
    df = get_daily_tests_timeseries(dtime, ndays=ndays)
    return df.diff(axis=1).fillna(0).sum(axis=0)

def get_daily_new_tests_by_state_timeseries(dtime, ndays=30):
    df = get_daily_tests_timeseries(dtime, ndays=ndays)
    return df.diff(axis=1).fillna(0)

# %%
get_daily_tests_timeseries(datetime.now() - timedelta(days=1), ndays=10)
# Out:
#                       09-20-2020  09-21-2020  09-22-2020  09-23-2020  \
# Province_State
# Alabama                1054017.0   1059517.0   1065553.0   1070903.0
# Alaska                  426925.0    428645.0    431191.0    433198.0
# Arizona                1383924.0   1390962.0   1400654.0   1409866.0
# Arkansas                883984.0    891524.0    897997.0    906947.0
# California            13523158.0  13672782.0  13804055.0  13879423.0
# Colorado               1195379.0   1208425.0   1219137.0   1232288.0
# Connecticut            1422148.0   1467766.0   1479824.0   1489898.0
# Delaware                271421.0    273213.0    274837.0    276044.0
# District of Columbia    355144.0    357744.0    361633.0    363448.0
# Florida                5095089.0   5113260.0   5132342.0   5155980.0
# Georgia                2750822.0   2770863.0   2783427.0   2803215.0
# Guam                     45958.0     46354.0     46828.0     47251.0
# Hawaii                  279849.0    281418.0    282580.0    284069.0
# Idaho                   286830.0    289163.0    290911.0    292159.0
# Illinois               5107351.0   5145585.0   5187414.0   5233805.0
# Indiana                1301940.0   1308645.0   1315440.0   1322819.0
# Iowa                    718279.0    721595.0    725082.0    731853.0
# Kansas                  474749.0    484691.0    484691.0    492281.0
# Kentucky               1047995.0   1058483.0   1068466.0   1216779.0
# Louisiana              2178999.0   2185792.0   2206974.0   2220009.0
# Maine                   374138.0    375392.0    375432.0    386035.0
# Maryland               1529476.0   1537629.0   1544014.0   1552105.0
# Massachusetts          3399512.0   3436161.0   3476679.0   3476679.0
# Michigan               3318469.0   3370667.0   3390878.0   3425107.0
# Minnesota              1838392.0   1855308.0   1863694.0   1873867.0
# Mississippi             703163.0    706906.0    712501.0    716711.0
# Missouri               1212508.0   1219559.0   1241749.0   1244563.0
# Montana                 302813.0    311262.0    314009.0    317160.0
# Nebraska                423360.0    425816.0    428046.0    431102.0
# Nevada                  665184.0    666792.0    669074.0    671924.0
# New Hampshire           401689.0    401689.0    410466.0    413391.0
# New Jersey             3352791.0   3353183.0   3397649.0   3422747.0
# New Mexico              857456.0    862899.0    866683.0    872331.0
# New York               9922446.0   9980765.0  10064762.0  10135692.0
# North Carolina         2804818.0   2817539.0   2824929.0   2842427.0
# North Dakota            562599.0    565843.0    568540.0    575479.0
# Ohio                   2825297.0   2856161.0   2888787.0   2931199.0
# Oklahoma               1072504.0   1073605.0   1101839.0   1114326.0
# Oregon                  636069.0    638798.0    642581.0    646125.0
# Pennsylvania           1908910.0   1917993.0   1929562.0   1942956.0
# Puerto Rico             347810.0    348448.0    348568.0    348632.0
# Rhode Island            675108.0    690281.0    696808.0    706578.0
# South Carolina         1132595.0   1144118.0   1172484.0   1190584.0
# South Dakota            176353.0    177023.0    178346.0    180132.0
# Tennessee              2667126.0   2679406.0   2691404.0   2713343.0
# Texas                  5593488.0   5622498.0   5667732.0   5740674.0
# Utah                    758165.0    762051.0    768959.0    775858.0
# Vermont                 155895.0    156739.0    157341.0    157263.0
# Virginia               1882028.0   1898637.0   1911580.0   1922606.0
# Washington             1723040.0   1736556.0   1736556.0   1740899.0
# West Virginia           514304.0    519516.0    522669.0    525580.0
# Wisconsin              1439394.0   1446215.0   1458819.0   1472405.0
# Wyoming                  92431.0     94131.0     94840.0     94993.0
#
#                       09-24-2020  09-25-2020  09-26-2020  09-27-2020  \
# Province_State
# Alabama                1078180.0   1097595.0   1104932.0   1111239.0
# Alaska                  433198.0    441332.0    442869.0    442869.0
# Arizona                1420417.0   1423603.0   1434227.0   1443323.0
# Arkansas                917413.0    926294.0    933895.0    940627.0
# California            13952857.0  14052247.0  14182730.0  14333498.0
# Colorado               1245745.0   1260861.0   1277613.0   1295655.0
# Connecticut            1505473.0   1519151.0   1519151.0   1519151.0
# Delaware                277916.0    279374.0    280399.0    282024.0
# District of Columbia    367867.0    373586.0    377979.0    381159.0
# Florida                5179499.0   5205994.0   5235007.0   5253441.0
# Georgia                2824816.0   2847494.0   2872355.0   2886269.0
# Guam                     47687.0     48256.0     48719.0     48719.0
# Hawaii                  286785.0    286875.0    289967.0    291657.0
# Idaho                   294063.0    296412.0    298652.0    301206.0
# Illinois               5295876.0   5365960.0   5431177.0   5481999.0
# Indiana                1331608.0   1341462.0   1350390.0   1358860.0
# Iowa                    738580.0    744981.0    750898.0    754623.0
# Kansas                  492281.0    502770.0    502770.0    502770.0
# Kentucky               1226385.0   1244628.0   1274688.0   1274688.0
# Louisiana              2237534.0   2256065.0   2256065.0   2283149.0
# Maine                   399966.0    406394.0    406419.0    421196.0
# Maryland               1561579.0   1572484.0   1584300.0   1594363.0
# Massachusetts          3642716.0   3706728.0   3780020.0   3881846.0
# Michigan               3462824.0   3502312.0   3543057.0   3543057.0
# Minnesota              1895302.0   1924020.0   1954715.0   1981100.0
# Mississippi             721759.0    726386.0    730713.0    730895.0
# Missouri               1259531.0   1273165.0   1289169.0   1298106.0
# Montana                 321518.0    326116.0    329285.0    330307.0
# Nebraska                434369.0    437304.0    440645.0    445129.0
# Nevada                  675488.0    681336.0    685678.0    688956.0
# New Hampshire           417689.0    417689.0    422591.0    422591.0
# New Jersey             3451804.0   3478711.0   3512568.0   3513266.0
# New Mexico              878406.0    885373.0    893489.0    899937.0
# New York              10228645.0  10323463.0  10423416.0  10508186.0
# North Carolina         2870191.0   2903054.0   2947803.0   2978728.0
# North Dakota            582104.0    587564.0    594628.0    600067.0
# Ohio                   2955715.0   2995593.0   3033987.0   3071187.0
# Oklahoma               1126926.0   1140664.0   1158985.0   1158985.0
# Oregon                  650498.0    662906.0    668671.0    671490.0
# Pennsylvania           1956867.0   1970600.0   1985524.0   2001220.0
# Puerto Rico             349814.0    350877.0    351385.0    352276.0
# Rhode Island            717047.0    727469.0    727469.0    727469.0
# South Carolina         1207106.0   1226467.0   1242797.0   1252538.0
# South Dakota            181661.0    183947.0    186134.0    187504.0
# Tennessee              2729388.0   2762845.0   2789879.0   2832536.0
# Texas                  5860833.0   5913449.0   5994813.0   6016907.0
# Utah                    784975.0    795217.0    805079.0    811249.0
# Vermont                 158189.0    159279.0    160276.0    160990.0
# Virginia               1952965.0   1973499.0   1993344.0   2003129.0
# Washington             1743296.0   1783279.0   1801021.0   1820623.0
# West Virginia           529025.0    535394.0    542291.0    549723.0
# Wisconsin              1485770.0   1500974.0   1513643.0   1521696.0
# Wyoming                  96640.0     97826.0     97871.0     98039.0
#
#                       09-28-2020  09-29-2020  09-30-2020
# Province_State
# Alabama                1116346.0   1119712.0   1132039.0
# Alaska                  444791.0    451056.0    457207.0
# Arizona                1448712.0   1453528.0   1457575.0
# Arkansas                997698.0   1007905.0   1029717.0
# California            14484852.0  14613545.0  14705202.0
# Colorado               1313403.0   1326642.0   1341180.0
# Connecticut            1571206.0   1581592.0   1593993.0
# Delaware                283815.0    285488.0    286562.0
# District of Columbia    383048.0    386396.0    387860.0
# Florida                5261672.0   5290116.0   5301184.0
# Georgia                2898498.0   2910833.0   2933679.0
# Guam                     49211.0     49727.0     50114.0
# Hawaii                  293562.0    296414.0    296501.0
# Idaho                   303252.0    304891.0    306706.0
# Illinois               5523141.0   5568765.0   5627311.0
# Indiana                1366294.0   1371355.0   1379850.0
# Iowa                    755316.0    758388.0    764867.0
# Kansas                  513909.0    513909.0    521450.0
# Kentucky               1293140.0   1362929.0   1375987.0
# Louisiana              2289618.0   2307757.0   2318604.0
# Maine                   423396.0    428054.0    435100.0
# Maryland               1603099.0   1610310.0   1618007.0
# Massachusetts          3931219.0   3988224.0   4050617.0
# Michigan               3593990.0   3618084.0   3647862.0
# Minnesota              2003115.0   2017350.0   2030167.0
# Mississippi             735892.0    736481.0    737033.0
# Missouri               1302958.0   1303034.0   1304385.0
# Montana                 337196.0    339926.0    343158.0
# Nebraska                448361.0    452557.0    455638.0
# Nevada                  692673.0    695720.0    698096.0
# New Hampshire           432396.0    438972.0    438972.0
# New Jersey             3566304.0   3566760.0   3613032.0
# New Mexico              905329.0    909505.0    914986.0
# New York              10561122.0  10649353.0  10747313.0
# North Carolina         3004533.0   3019586.0   3034871.0
# North Dakota            603922.0    608385.0    613487.0
# Ohio                   3106176.0   3141377.0   3165935.0
# Oklahoma               1160669.0   1192403.0   1204028.0
# Oregon                  675029.0    679383.0    685873.0
# Pennsylvania           2012317.0   2024575.0   2038094.0
# Puerto Rico             353394.0    354439.0    354727.0
# Rhode Island            753156.0    760228.0    769822.0
# South Carolina         1273928.0   1300414.0   1309098.0
# South Dakota            188344.0    189146.0    190769.0
# Tennessee              2847342.0   2860481.0   2884356.0
# Texas                  6171755.0   6200826.0   6237157.0
# Utah                    817461.0    821864.0    829970.0
# Vermont                 161925.0    162747.0    162727.0
# Virginia               2027168.0   2039510.0   2049988.0
# Washington             1837206.0   1848463.0   1854399.0
# West Virginia           553270.0    558313.0    561568.0
# Wisconsin              1529594.0   1540438.0   1552370.0
# Wyoming                 100116.0    100543.0    101160.0

# %%
get_daily_new_tests_by_state_timeseries(datetime.now() - timedelta(days=1), ndays=10)
# Out:
#                       09-20-2020  09-21-2020  09-22-2020  09-23-2020  \
# Province_State
# Alabama                      0.0      5500.0      6036.0      5350.0
# Alaska                       0.0      1720.0      2546.0      2007.0
# Arizona                      0.0      7038.0      9692.0      9212.0
# Arkansas                     0.0      7540.0      6473.0      8950.0
# California                   0.0    149624.0    131273.0     75368.0
# Colorado                     0.0     13046.0     10712.0     13151.0
# Connecticut                  0.0     45618.0     12058.0     10074.0
# Delaware                     0.0      1792.0      1624.0      1207.0
# District of Columbia         0.0      2600.0      3889.0      1815.0
# Florida                      0.0     18171.0     19082.0     23638.0
# Georgia                      0.0     20041.0     12564.0     19788.0
# Guam                         0.0       396.0       474.0       423.0
# Hawaii                       0.0      1569.0      1162.0      1489.0
# Idaho                        0.0      2333.0      1748.0      1248.0
# Illinois                     0.0     38234.0     41829.0     46391.0
# Indiana                      0.0      6705.0      6795.0      7379.0
# Iowa                         0.0      3316.0      3487.0      6771.0
# Kansas                       0.0      9942.0         0.0      7590.0
# Kentucky                     0.0     10488.0      9983.0    148313.0
# Louisiana                    0.0      6793.0     21182.0     13035.0
# Maine                        0.0      1254.0        40.0     10603.0
# Maryland                     0.0      8153.0      6385.0      8091.0
# Massachusetts                0.0     36649.0     40518.0         0.0
# Michigan                     0.0     52198.0     20211.0     34229.0
# Minnesota                    0.0     16916.0      8386.0     10173.0
# Mississippi                  0.0      3743.0      5595.0      4210.0
# Missouri                     0.0      7051.0     22190.0      2814.0
# Montana                      0.0      8449.0      2747.0      3151.0
# Nebraska                     0.0      2456.0      2230.0      3056.0
# Nevada                       0.0      1608.0      2282.0      2850.0
# New Hampshire                0.0         0.0      8777.0      2925.0
# New Jersey                   0.0       392.0     44466.0     25098.0
# New Mexico                   0.0      5443.0      3784.0      5648.0
# New York                     0.0     58319.0     83997.0     70930.0
# North Carolina               0.0     12721.0      7390.0     17498.0
# North Dakota                 0.0      3244.0      2697.0      6939.0
# Ohio                         0.0     30864.0     32626.0     42412.0
# Oklahoma                     0.0      1101.0     28234.0     12487.0
# Oregon                       0.0      2729.0      3783.0      3544.0
# Pennsylvania                 0.0      9083.0     11569.0     13394.0
# Puerto Rico                  0.0       638.0       120.0        64.0
# Rhode Island                 0.0     15173.0      6527.0      9770.0
# South Carolina               0.0     11523.0     28366.0     18100.0
# South Dakota                 0.0       670.0      1323.0      1786.0
# Tennessee                    0.0     12280.0     11998.0     21939.0
# Texas                        0.0     29010.0     45234.0     72942.0
# Utah                         0.0      3886.0      6908.0      6899.0
# Vermont                      0.0       844.0       602.0       -78.0
# Virginia                     0.0     16609.0     12943.0     11026.0
# Washington                   0.0     13516.0         0.0      4343.0
# West Virginia                0.0      5212.0      3153.0      2911.0
# Wisconsin                    0.0      6821.0     12604.0     13586.0
# Wyoming                      0.0      1700.0       709.0       153.0
#
#                       09-24-2020  09-25-2020  09-26-2020  09-27-2020  \
# Province_State
# Alabama                   7277.0     19415.0      7337.0      6307.0
# Alaska                       0.0      8134.0      1537.0         0.0
# Arizona                  10551.0      3186.0     10624.0      9096.0
# Arkansas                 10466.0      8881.0      7601.0      6732.0
# California               73434.0     99390.0    130483.0    150768.0
# Colorado                 13457.0     15116.0     16752.0     18042.0
# Connecticut              15575.0     13678.0         0.0         0.0
# Delaware                  1872.0      1458.0      1025.0      1625.0
# District of Columbia      4419.0      5719.0      4393.0      3180.0
# Florida                  23519.0     26495.0     29013.0     18434.0
# Georgia                  21601.0     22678.0     24861.0     13914.0
# Guam                       436.0       569.0       463.0         0.0
# Hawaii                    2716.0        90.0      3092.0      1690.0
# Idaho                     1904.0      2349.0      2240.0      2554.0
# Illinois                 62071.0     70084.0     65217.0     50822.0
# Indiana                   8789.0      9854.0      8928.0      8470.0
# Iowa                      6727.0      6401.0      5917.0      3725.0
# Kansas                       0.0     10489.0         0.0         0.0
# Kentucky                  9606.0     18243.0     30060.0         0.0
# Louisiana                17525.0     18531.0         0.0     27084.0
# Maine                    13931.0      6428.0        25.0     14777.0
# Maryland                  9474.0     10905.0     11816.0     10063.0
# Massachusetts           166037.0     64012.0     73292.0    101826.0
# Michigan                 37717.0     39488.0     40745.0         0.0
# Minnesota                21435.0     28718.0     30695.0     26385.0
# Mississippi               5048.0      4627.0      4327.0       182.0
# Missouri                 14968.0     13634.0     16004.0      8937.0
# Montana                   4358.0      4598.0      3169.0      1022.0
# Nebraska                  3267.0      2935.0      3341.0      4484.0
# Nevada                    3564.0      5848.0      4342.0      3278.0
# New Hampshire             4298.0         0.0      4902.0         0.0
# New Jersey               29057.0     26907.0     33857.0       698.0
# New Mexico                6075.0      6967.0      8116.0      6448.0
# New York                 92953.0     94818.0     99953.0     84770.0
# North Carolina           27764.0     32863.0     44749.0     30925.0
# North Dakota              6625.0      5460.0      7064.0      5439.0
# Ohio                     24516.0     39878.0     38394.0     37200.0
# Oklahoma                 12600.0     13738.0     18321.0         0.0
# Oregon                    4373.0     12408.0      5765.0      2819.0
# Pennsylvania             13911.0     13733.0     14924.0     15696.0
# Puerto Rico               1182.0      1063.0       508.0       891.0
# Rhode Island             10469.0     10422.0         0.0         0.0
# South Carolina           16522.0     19361.0     16330.0      9741.0
# South Dakota              1529.0      2286.0      2187.0      1370.0
# Tennessee                16045.0     33457.0     27034.0     42657.0
# Texas                   120159.0     52616.0     81364.0     22094.0
# Utah                      9117.0     10242.0      9862.0      6170.0
# Vermont                    926.0      1090.0       997.0       714.0
# Virginia                 30359.0     20534.0     19845.0      9785.0
# Washington                2397.0     39983.0     17742.0     19602.0
# West Virginia             3445.0      6369.0      6897.0      7432.0
# Wisconsin                13365.0     15204.0     12669.0      8053.0
# Wyoming                   1647.0      1186.0        45.0       168.0
#
#                       09-28-2020  09-29-2020  09-30-2020
# Province_State
# Alabama                   5107.0      3366.0     12327.0
# Alaska                    1922.0      6265.0      6151.0
# Arizona                   5389.0      4816.0      4047.0
# Arkansas                 57071.0     10207.0     21812.0
# California              151354.0    128693.0     91657.0
# Colorado                 17748.0     13239.0     14538.0
# Connecticut              52055.0     10386.0     12401.0
# Delaware                  1791.0      1673.0      1074.0
# District of Columbia      1889.0      3348.0      1464.0
# Florida                   8231.0     28444.0     11068.0
# Georgia                  12229.0     12335.0     22846.0
# Guam                       492.0       516.0       387.0
# Hawaii                    1905.0      2852.0        87.0
# Idaho                     2046.0      1639.0      1815.0
# Illinois                 41142.0     45624.0     58546.0
# Indiana                   7434.0      5061.0      8495.0
# Iowa                       693.0      3072.0      6479.0
# Kansas                   11139.0         0.0      7541.0
# Kentucky                 18452.0     69789.0     13058.0
# Louisiana                 6469.0     18139.0     10847.0
# Maine                     2200.0      4658.0      7046.0
# Maryland                  8736.0      7211.0      7697.0
# Massachusetts            49373.0     57005.0     62393.0
# Michigan                 50933.0     24094.0     29778.0
# Minnesota                22015.0     14235.0     12817.0
# Mississippi               4997.0       589.0       552.0
# Missouri                  4852.0        76.0      1351.0
# Montana                   6889.0      2730.0      3232.0
# Nebraska                  3232.0      4196.0      3081.0
# Nevada                    3717.0      3047.0      2376.0
# New Hampshire             9805.0      6576.0         0.0
# New Jersey               53038.0       456.0     46272.0
# New Mexico                5392.0      4176.0      5481.0
# New York                 52936.0     88231.0     97960.0
# North Carolina           25805.0     15053.0     15285.0
# North Dakota              3855.0      4463.0      5102.0
# Ohio                     34989.0     35201.0     24558.0
# Oklahoma                  1684.0     31734.0     11625.0
# Oregon                    3539.0      4354.0      6490.0
# Pennsylvania             11097.0     12258.0     13519.0
# Puerto Rico               1118.0      1045.0       288.0
# Rhode Island             25687.0      7072.0      9594.0
# South Carolina           21390.0     26486.0      8684.0
# South Dakota               840.0       802.0      1623.0
# Tennessee                14806.0     13139.0     23875.0
# Texas                   154848.0     29071.0     36331.0
# Utah                      6212.0      4403.0      8106.0
# Vermont                    935.0       822.0       -20.0
# Virginia                 24039.0     12342.0     10478.0
# Washington               16583.0     11257.0      5936.0
# West Virginia             3547.0      5043.0      3255.0
# Wisconsin                 7898.0     10844.0     11932.0
# Wyoming                   2077.0       427.0       617.0

# %%
get_daily_tests_timeseries(datetime.now() - timedelta(days=1)).sum(axis=0)
# Out:
# 08-31-2020     78261033.0
# 09-01-2020     78964825.0
# 09-02-2020     79614467.0
# 09-03-2020     80349237.0
# 09-04-2020     81261108.0
# 09-05-2020     82067096.0
# 09-06-2020     82805700.0
# 09-07-2020     83394514.0
# 09-08-2020     83932009.0
# 09-09-2020     84526002.0
# 09-10-2020     85147267.0
# 09-11-2020     87193012.0
# 09-12-2020     88014216.0
# 09-13-2020     88785571.0
# 09-14-2020     89569389.0
# 09-15-2020     89953215.0
# 09-16-2020     90676110.0
# 09-17-2020     91511870.0
# 09-18-2020     93115149.0
# 09-19-2020     94176560.0
# 09-20-2020     95073292.0
# 09-21-2020     95806013.0
# 09-22-2020     96577016.0
# 09-23-2020     97423708.0
# 09-24-2020     98444786.0
# 09-25-2020     99447324.0
# 09-26-2020    100456148.0
# 09-27-2020    101262217.0
# 09-28-2020    102305839.0
# 09-29-2020    103118399.0
# 09-30-2020    103902353.0
# dtype: float64

# %%
# get_daily_new_tests_timeseries(datetime.now() - timedelta(days=1), ndays=30)
# get_daily_new_tests_timeseries(datetime.now() - timedelta(days=1), ndays=90).rolling(7, min_periods=1).mean()
get_daily_new_tests_timeseries(datetime.now() - timedelta(days=1), ndays=50)
# Out:
# 08-11-2020          0.0
# 08-12-2020     462937.0
# 08-13-2020    1115525.0
# 08-14-2020     844968.0
# 08-15-2020     743831.0
# 08-16-2020     782474.0
# 08-17-2020     852696.0
# 08-18-2020     648537.0
# 08-19-2020     664464.0
# 08-20-2020     661030.0
# 08-21-2020     771289.0
# 08-22-2020     756770.0
# 08-23-2020     622311.0
# 08-24-2020     706704.0
# 08-25-2020     645741.0
# 08-26-2020    1012955.0
# 08-27-2020     751327.0
# 08-28-2020     783052.0
# 08-29-2020     764922.0
# 08-30-2020     740933.0
# 08-31-2020     701070.0
# 09-01-2020     703792.0
# 09-02-2020     649642.0
# 09-03-2020     734770.0
# 09-04-2020     911871.0
# 09-05-2020     805988.0
# 09-06-2020     738604.0
# 09-07-2020     588814.0
# 09-08-2020     537495.0
# 09-09-2020     593993.0
# 09-10-2020     621265.0
# 09-11-2020    2045745.0
# 09-12-2020     821204.0
# 09-13-2020     771355.0
# 09-14-2020     783818.0
# 09-15-2020     383826.0
# 09-16-2020     722895.0
# 09-17-2020     835760.0
# 09-18-2020    1603279.0
# 09-19-2020    1061411.0
# 09-20-2020     896732.0
# 09-21-2020     732721.0
# 09-22-2020     771003.0
# 09-23-2020     846692.0
# 09-24-2020    1021078.0
# 09-25-2020    1002538.0
# 09-26-2020    1008824.0
# 09-27-2020     806069.0
# 09-28-2020    1043622.0
# 09-29-2020     812560.0
# 09-30-2020     783954.0
# dtype: float64

# %%
dtime = datetime.now() - timedelta(days=1)
col = datetime_to_str(dtime)
get_daily_new_tests_by_state_timeseries(dtime, ndays=1).sort_values(col, axis=0, ascending=False)[col]
# Out:
# Province_State
# New York                97960.0
# California              91657.0
# Massachusetts           62393.0
# Illinois                58546.0
# New Jersey              46272.0
# Texas                   36331.0
# Michigan                29778.0
# Ohio                    24558.0
# Tennessee               23875.0
# Georgia                 22846.0
# Arkansas                21812.0
# North Carolina          15285.0
# Colorado                14538.0
# Pennsylvania            13519.0
# Kentucky                13058.0
# Minnesota               12817.0
# Connecticut             12401.0
# Alabama                 12327.0
# Wisconsin               11932.0
# Oklahoma                11625.0
# Florida                 11068.0
# Louisiana               10847.0
# Virginia                10478.0
# Rhode Island             9594.0
# South Carolina           8684.0
# Indiana                  8495.0
# Utah                     8106.0
# Maryland                 7697.0
# Kansas                   7541.0
# Maine                    7046.0
# Oregon                   6490.0
# Iowa                     6479.0
# Alaska                   6151.0
# Washington               5936.0
# New Mexico               5481.0
# North Dakota             5102.0
# Arizona                  4047.0
# West Virginia            3255.0
# Montana                  3232.0
# Nebraska                 3081.0
# Nevada                   2376.0
# Idaho                    1815.0
# South Dakota             1623.0
# District of Columbia     1464.0
# Missouri                 1351.0
# Delaware                 1074.0
# Wyoming                   617.0
# Mississippi               552.0
# Guam                      387.0
# Puerto Rico               288.0
# Hawaii                     87.0
# New Hampshire               0.0
# Vermont                   -20.0
# Name: 09-30-2020, dtype: float64

# %%
def get_hospitalized_data(dtime):
    exclude = [
        'Diamond Princess',
        'Grand Princess',
        'American Samoa',
        'Virgin Islands',
        'Northern Mariana Islands'
    ]
    file = '{0}.csv'.format(datetime_to_str(dtime))
    df = pd.read_csv('csse_covid_19_data/csse_covid_19_daily_reports_us/{0}'.format(file),
                     usecols=['Province_State', 'People_Hospitalized']).fillna(0)
    df = df[~df.Province_State.isin(exclude)] # not isin
    df.rename(columns={ 'People_Hospitalized': datetime_to_str(dtime) }, inplace=True)
    df.set_index(['Province_State'], inplace=True)
    return df

def get_daily_hospitalized_timeseries(dtime, ndays=30):
    df = get_hospitalized_data(dtime)
    for days in range(1, ndays+1):
        df_2 = get_hospitalized_data(dtime - timedelta(days=days))
        df = pd.concat([df_2, df], axis=1, join='inner')
    return df

def get_daily_new_hospitalized_timeseries(dtime, ndays=30):
    df = get_daily_hospitalized_timeseries(dtime, ndays=ndays)
    return df.diff(axis=1).fillna(0).sum(axis=0)

def get_daily_new_hospitalized_by_state_timeseries(dtime, ndays=30):
    df = get_daily_hospitalized_timeseries(dtime, ndays=ndays)
    return df.diff(axis=1).fillna(0)

# %%
# get_daily_hospitalized_timeseries(datetime.now() - timedelta(days=1), ndays=10)

# %%
# get_daily_new_hospitalized_timeseries(datetime.now() - timedelta(days=1), ndays=30)

# %%
# get_daily_new_hospitalized_by_state_timeseries(datetime.now() - timedelta(days=1), ndays=10)

# %%
# dtime = datetime.now() - timedelta(days=1)
# col = datetime_to_str(dtime)
# get_daily_new_hospitalized_by_state_timeseries(dtime, ndays=14).sort_values(col, axis=0, ascending=False)[col]

# %%
def get_daily_data(dtime, col):
    exclude = [
        'Diamond Princess',
        'Grand Princess',
        'American Samoa',
        'Virgin Islands',
        'Northern Mariana Islands',
        'Puerto Rico',
    ]
    file = '{0}.csv'.format(datetime_to_str(dtime))
    df = pd.read_csv('csse_covid_19_data/csse_covid_19_daily_reports_us/{0}'.format(file),
                     usecols=['Province_State', col]).fillna(0)
    df = df[~df.Province_State.isin(exclude)] # not isin
    df.set_index(['Province_State'], inplace=True)
    return df

def get_daily_confirmed(dtime):
    conf_curr = get_daily_data(dtime, 'Confirmed')
    conf_prev = get_daily_data(dtime - timedelta(days=1), 'Confirmed')
    conf = (conf_curr - conf_prev)
    conf.rename(columns={'Confirmed': datetime_to_str(dtime)}, inplace=True)
    return conf

def get_daily_tested(dtime, lag=0):
    tstd_curr = get_daily_data(dtime - timedelta(days=lag), 'People_Tested')
    tstd_prev = get_daily_data(dtime - timedelta(days=lag+1), 'People_Tested')
    tstd = (tstd_curr - tstd_prev)
    tstd.rename(columns={'People_Tested': datetime_to_str(dtime)}, inplace=True)
    return tstd

def get_confirmed_timeseries(dtime, ndays=10):
    df = get_daily_confirmed(dtime)
    for days in range(1, ndays+1):
        df_2 = get_daily_confirmed(dtime - timedelta(days=days))
        df = pd.concat([df_2, df], axis=1, join='inner')
    return df.rolling(7, axis=1, min_periods=1).mean()

def get_tested_timeseries(dtime, lag=0, ndays=10):
    df = get_daily_tested(dtime, lag=lag)
    for days in range(1, ndays+1):
        df_2 = get_daily_tested(dtime - timedelta(days=days), lag=lag)
        df = pd.concat([df_2, df], axis=1, join='inner')
    return df.rolling(7, axis=1, min_periods=1).mean()
    
def get_pct_plus(dtime, ndays=10, lag=0):
    conf = get_confirmed_timeseries(dtime, ndays=ndays)
    tstd = get_tested_timeseries(dtime, ndays=ndays)
    return 100 * conf / tstd

# get_daily_confirmed(datetime.now() - timedelta(days=2))
# get_daily_tested(datetime.now() - timedelta(days=2))
# get_confirmed_timeseries(datetime.now() - timedelta(days=2))
# get_tested_timeseries(datetime.now() - timedelta(days=2))
# get_pct_plus(datetime.now() - timedelta(days=2), lag=1)
# get_pct_plus(datetime.now() - timedelta(days=2), lag=2)
# get_pct_plus(datetime.now() - timedelta(days=2), lag=3)
# get_pct_plus(datetime.now() - timedelta(days=2), lag=4)
get_pct_plus(datetime.now() - timedelta(days=1), ndays=10, lag=0)
# Out:
#                       09-20-2020  09-21-2020  09-22-2020  09-23-2020  \
# Province_State
# Alabama                14.262735   14.565119   14.126437   13.295672
# Alaska                  2.282209    2.812770    2.481717    2.657518
# Arizona                 4.366001    3.931922    4.709947    4.721170
# Arkansas                3.208160    4.798916    5.769596    6.918938
# California              1.592552    2.062354    2.119221    2.450438
# Colorado                3.697417    3.921642    4.548622    4.583920
# Connecticut                  NaN    1.089482    1.097510    1.163100
# Delaware                6.842105    6.225014    6.086617    6.016106
# District of Columbia    1.242090    1.106742    1.106359    1.177313
# Florida                 9.500660    9.408133   10.465918   10.598678
# Georgia                 7.347891    6.534363    6.813356    7.578215
# Guam                         NaN   18.434343   13.333333   12.451663
# Hawaii                 70.642202    7.926103    6.901408    8.385308
# Idaho                  14.412286   16.244411   19.050918   21.304472
# Illinois                2.920164    3.338165    3.444883    3.589259
# Indiana                 8.000000    7.910168    8.179628    8.535293
# Iowa                   13.454707   15.383632   16.043159   16.965372
# Kansas                       inf   11.476564   15.228324   13.461100
# Kentucky                     inf    7.732647    7.938059    1.427268
# Louisiana               2.923812    3.038190    3.218977    3.234597
# Maine                   1.457133    1.712247    2.638398    0.915948
# Maryland                3.860570    4.377158    4.633082    4.663524
# Massachusetts           0.576985    0.622035    0.565332    0.954895
# Michigan                     NaN    3.017357    3.134969    2.974549
# Minnesota               5.729950    5.617949    5.636477    5.816536
# Mississippi           100.000000   11.666667    9.713989   10.748644
# Missouri               13.213274   15.783880    9.579553   12.735163
# Montana                 6.893056    2.552293    4.077758    4.589461
# Nebraska                8.499257   10.152895   12.271767   13.333934
# Nevada                  8.559360   10.104815   10.479256   12.350952
# New Hampshire           0.316790    0.375455    0.404624    0.430161
# New Jersey              0.749826    1.389665    1.207349    1.287873
# New Mexico              1.031880    1.432641    1.768448    2.222950
# New York                0.858951    0.904370    0.902044    0.910074
# North Carolina          3.846381    4.531482    6.123282    5.955999
# North Dakota            6.118180    7.092751    7.715362    7.380351
# Ohio                    2.081853    2.398245    2.300883    2.249761
# Oklahoma              100.000000  100.000000   10.771969   10.173964
# Oregon                  9.356183    8.101473    8.234344    7.400737
# Pennsylvania            4.935471    6.662703    6.702156    6.619547
# Rhode Island                 NaN    2.056284    1.953917    1.769940
# South Carolina          5.016077    4.239198    7.210630    6.604376
# South Dakota           22.261484   23.584906   23.840000   24.231317
# Tennessee               5.182447    5.676714    5.766749    6.212901
# Texas                  16.716152   45.241226   32.253529   19.703321
# Utah                   14.802896   15.265815   12.887295   12.836707
# Vermont                 0.456621    0.464157    0.432900    0.487211
# Virginia                5.526624    4.616684    5.205504    5.207365
# Washington              1.899837    1.665308    3.117356    4.148610
# West Virginia           3.590702    2.911266    3.830691    3.889648
# Wisconsin              19.845054   19.301821   16.566601   15.386102
# Wyoming               100.000000    9.101061    9.400000   14.624953
#
#                       09-24-2020  09-25-2020  09-26-2020  09-27-2020  \
# Province_State
# Alabama                13.582902   13.206434   13.142807   12.860438
# Alaska                  3.894472    2.840602    3.186972    4.133216
# Arizona                 4.869017    5.582428    5.362874    5.414233
# Arkansas                7.628781    7.995456    8.293804    9.743481
# California              2.660718    2.872405    2.877531    2.927413
# Colorado                4.474623    4.515892    4.335797    4.209382
# Connecticut             1.134113    1.092750    1.092750    1.092750
# Delaware                6.069470    6.581807    6.614895    6.545317
# District of Columbia    1.200706    1.149324    1.154896    1.133961
# Florida                10.642210   10.662107   10.482839   10.615591
# Georgia                 7.466425    6.683912    6.462918    6.297666
# Guam                   10.931174    9.225413    7.678377    7.678377
# Hawaii                  6.430092    7.918711    6.766403    6.038279
# Idaho                  22.260811   22.261641   22.560118   20.937674
# Illinois                3.601143    3.682408    3.693016    3.718157
# Indiana                 8.916985    9.515426   10.021636   10.444483
# Iowa                   16.879661   16.749984   16.442637   17.097733
# Kansas                 16.005019   14.057314   14.870990   14.895971
# Kentucky                1.710858    2.013904    2.174747    2.183129
# Louisiana               3.245792    3.341615    3.341615    3.487278
# Maine                   0.625456    0.568069    0.635786    0.446258
# Maryland                4.806546    4.871461    4.928545    5.004084
# Massachusetts           0.593274    0.622571    0.648028    0.643123
# Michigan                2.944131    2.877455    2.798903    2.798903
# Minnesota               5.395584    5.051457    4.993486    4.706814
# Mississippi            11.778732   12.531915   12.901139   12.602769
# Missouri               11.768324   12.180151   12.296493   12.682539
# Montana                 5.218106    5.542807    6.131130    6.575980
# Nebraska               13.454849   13.663412   13.554479   13.689191
# Nevada                 12.011890   11.302663   11.747759   12.300185
# New Hampshire           0.505648    0.672838    0.683093    1.076452
# New Jersey              1.196159    1.497848    1.608149    2.359246
# New Mexico              2.594469    2.833479    2.774773    2.977802
# New York                0.936899    0.940818    0.951565    0.977567
# North Carolina          5.989654    9.151431    7.813534    7.936289
# North Dakota            7.305285    7.419712    7.342583    7.382300
# Ohio                    2.512873    2.584365    2.634411    2.643458
# Oklahoma                9.815065    9.710394    8.808468    8.702490
# Oregon                  7.632023    5.914609    5.701792    5.700008
# Pennsylvania            6.494682    6.415576    6.372555    6.366591
# Rhode Island            1.647631    1.071408    1.071408    1.071408
# South Carolina          6.520676    6.455301    6.720376    6.819072
# South Dakota           25.667702   24.180610   24.640337   25.513407
# Tennessee               6.110400    5.903888    5.806182    5.731818
# Texas                  13.245447   12.312682   10.743055   10.804664
# Utah                   12.920515   13.123165   12.601404   12.890890
# Vermont                 0.413101    0.468855    0.529584    0.529931
# Virginia                4.416042    4.444320    4.516175    4.629194
# Washington              5.278828    3.850704    3.768513    3.813164
# West Virginia           4.247914    4.141578    3.895748    3.639290
# Wisconsin              15.998977   16.101186   17.041591   17.782071
# Wyoming                12.186047   11.647831   12.366661   13.569900
#
#                       09-28-2020  09-29-2020  09-30-2020
# Province_State
# Alabama                12.674867   12.869514   12.346244
# Alaska                  4.366407    3.956708    3.415386
# Arizona                 5.643290    6.313122    6.755539
# Arkansas                5.354418    5.253485    4.670522
# California              2.784858    2.790522    2.746376
# Colorado                3.896054    3.693782    3.550307
# Connecticut             1.085654    1.148691    1.186416
# Delaware                6.810036    7.229368    7.444381
# District of Columbia    1.130256    1.126681    1.130592
# Florida                10.688489   10.558774   11.030688
# Georgia                 6.222431    6.288558    6.028483
# Guam                    4.865243    8.727147    8.836884
# Hawaii                  6.126482    5.551540    5.799550
# Idaho                  21.449358   22.081545   22.719461
# Illinois                3.750967    3.669847    3.663731
# Indiana                10.919530   11.517482   11.716435
# Iowa                   18.534444   19.867291   19.313019
# Kansas                 14.840167   14.888083   14.378278
# Kentucky                2.140145    1.740456    3.344681
# Louisiana               3.495271    3.383507    3.436280
# Maine                   0.404133    0.362966    0.446347
# Maryland                5.058806    5.127006    5.201663
# Massachusetts           0.661741    0.706683    0.627942
# Michigan                2.704603    2.844555    3.032480
# Minnesota               4.530232    4.571901    4.500320
# Mississippi            12.050645   15.083403   17.798445
# Missouri               12.863464   16.185037   14.225536
# Montana                 7.650189    7.809546    8.304485
# Nebraska               14.149479   13.296071   13.392566
# Nevada                 12.190410   12.373339   12.123644
# New Hampshire           0.833686    0.852452    1.012470
# New Jersey              1.854815    2.355258    2.252936
# New Mexico              3.068584    3.192284    3.394678
# New York                1.031606    1.098546    1.104769
# North Carolina          7.417885    6.980484    7.343435
# North Dakota            7.192941    7.260635    7.537887
# Ohio                    2.654641    2.793856    3.081760
# Oklahoma                8.368556    7.891657    7.845979
# Oregon                  5.517375    5.374708    5.046795
# Pennsylvania            6.256096    7.054824    7.108621
# Rhode Island            0.782505    0.807316    0.902852
# South Carolina          6.417841    5.350582    5.278701
# South Dakota           25.342284   26.000000   25.900160
# Tennessee               5.551520    5.596858    5.462158
# Texas                   4.810134    4.802343    6.063853
# Utah                   12.719726   13.405160   13.159743
# Vermont                 0.501350    0.517943    0.549048
# Virginia                4.218438    4.268741    4.422132
# Washington              3.882762    3.439463    3.365639
# West Virginia           3.955087    3.644372    3.709570
# Wisconsin              18.098082   19.339860   20.436441
# Wyoming                13.533835   14.115378   12.631750

# %%
# Assumes a 3 day lag of testing results
dtime = datetime.now() - timedelta(days=1)
col = datetime_to_str(dtime)
get_pct_plus(dtime, ndays=10, lag=0).rolling(7, axis=1, min_periods=1).mean().sort_values(col, axis=0, ascending=False)[col]
# Out:
# Province_State
# South Dakota            25.320643
# Idaho                   22.038658
# Iowa                    17.840681
# Wisconsin               17.828315
# Kansas                  14.847975
# Nebraska                13.600007
# Mississippi             13.535293
# Missouri                13.171649
# Utah                    12.974372
# Alabama                 12.954744
# Wyoming                 12.864486
# Nevada                  12.007127
# Florida                 10.668671
# Indiana                 10.435997
# Texas                    8.968883
# Oklahoma                 8.734658
# Guam                     8.277517
# North Carolina           7.518959
# North Dakota             7.348763
# Arkansas                 6.991421
# Delaware                 6.756468
# Montana                  6.747463
# Pennsylvania             6.581278
# Georgia                  6.492913
# Hawaii                   6.375865
# South Carolina           6.223222
# Oregon                   5.841044
# Tennessee                5.737546
# Arizona                  5.705786
# Maryland                 4.999730
# Minnesota                4.821399
# Virginia                 4.416434
# Colorado                 4.096548
# Washington               3.914153
# West Virginia            3.890508
# Alaska                   3.684823
# Illinois                 3.682753
# Louisiana                3.390194
# New Mexico               2.976581
# Michigan                 2.857290
# California               2.808546
# Ohio                     2.700766
# Kentucky                 2.186846
# New Jersey               1.874916
# District of Columbia     1.146631
# Connecticut              1.119018
# Rhode Island             1.050647
# New York                 1.005967
# New Hampshire            0.805234
# Massachusetts            0.643337
# Vermont                  0.501402
# Maine                    0.498431
# Name: 09-30-2020, dtype: float64
