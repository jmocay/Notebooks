# %%
import pandas as pd
from datetime import datetime
from datetime import timedelta

# %%
def datetime_to_str(dtime):
    return '{0}-{1}-{2}'.format(str(dtime.month).zfill(2), str(dtime.day).zfill(2), str(dtime.year).zfill(4))
# datetime_to_str(datetime.now())

# %%
def get_tests_data(dtime):
    exclude = [
        'Diamond Princess',
        'Grand Princess',
        'American Samoa',
        'Virgin Islands',
        'Northern Mariana Islands'
    ]
    file = '{0}.csv'.format(datetime_to_str(dtime))
    df = pd.read_csv('csse_covid_19_data/csse_covid_19_daily_reports_us/{0}'.format(file),
                     usecols=['Province_State', 'People_Tested']).fillna(0)
    df = df[~df.Province_State.isin(exclude)] # not isin
    df.rename(columns={ 'People_Tested': datetime_to_str(dtime) }, inplace=True)
    df.set_index(['Province_State'], inplace=True)
    return df

def get_daily_tests_timeseries(dtime, ndays=30):
    df = get_tests_data(dtime)
    for days in range(1, ndays+1):
        df_2 = get_tests_data(dtime - timedelta(days=days))
        df = pd.concat([df_2, df], axis=1, join='inner')
    return df

def get_daily_new_tests_timeseries(dtime, ndays=30):
    df = get_daily_tests_timeseries(dtime, ndays=ndays)
    return df.diff(axis=1).fillna(0).sum(axis=0)

def get_daily_new_tests_by_state_timeseries(dtime, ndays=30):
    df = get_daily_tests_timeseries(dtime, ndays=ndays)
    return df.diff(axis=1).fillna(0)

# %%
get_daily_tests_timeseries(datetime.now() - timedelta(days=1), ndays=10)
# Out:
#                       09-30-2020  10-01-2020  10-02-2020  10-03-2020  \
# Province_State
# Alabama                1132039.0   1138732.0   1145601.0   1156045.0
# Alaska                  457207.0    462323.0    469290.0    473256.0
# Arizona                1457575.0   1471368.0   1478504.0   1488145.0
# Arkansas               1029717.0   1042616.0   1054260.0   1064738.0
# California            14705202.0  14771851.0  14868431.0  14998888.0
# Colorado               1341180.0   1357159.0   1376920.0   1396346.0
# Connecticut            1593993.0   1604380.0   1676410.0   1676410.0
# Delaware                286562.0    288217.0    290283.0    292458.0
# District of Columbia    387860.0    390180.0    394118.0    397549.0
# Florida                5301184.0   5325835.0   5351521.0   5376459.0
# Georgia                2933679.0   2954392.0   2970013.0   3001381.0
# Guam                     50114.0     50548.0     51118.0     51756.0
# Hawaii                  296501.0    298463.0    300459.0    302213.0
# Idaho                   306706.0    309156.0    311337.0    314442.0
# Illinois               5627311.0   5692926.0   5765867.0   5837501.0
# Indiana                1379850.0   1387731.0   1398522.0   1408475.0
# Iowa                    764867.0    770943.0    775992.0    781309.0
# Kansas                  521450.0    521450.0    531117.0    531117.0
# Kentucky               1375987.0   1399762.0   1422520.0   1434524.0
# Louisiana              2318604.0   2334745.0   2357449.0   2357449.0
# Maine                   435100.0    442391.0    449290.0    449308.0
# Maryland               1618007.0   1628200.0   1639785.0   1649725.0
# Massachusetts          4050617.0   4125104.0   4200018.0   4265786.0
# Michigan               3647862.0   3683581.0   3723748.0   3764274.0
# Minnesota              2030167.0   2055888.0   2086963.0   2116038.0
# Mississippi             737033.0    737729.0    738401.0    739010.0
# Missouri               1304385.0   1315418.0   1326189.0   1339556.0
# Montana                 343158.0    348709.0    353362.0    354783.0
# Nebraska                455638.0    459542.0    464264.0    469968.0
# Nevada                  698096.0    701557.0    706635.0    710210.0
# New Hampshire           438972.0    450814.0    455869.0    461049.0
# New Jersey             3613032.0   3613646.0   3672127.0   3673074.0
# New Mexico              914986.0    921009.0    928389.0    935401.0
# New York              10747313.0  10856531.0  10976024.0  11110291.0
# North Carolina         3034871.0   3063661.0   3099704.0   3136266.0
# North Dakota            613487.0    619331.0    626450.0    632299.0
# Ohio                   3165935.0   3240197.0   3271748.0   3318775.0
# Oklahoma               1204028.0   1215441.0   1230160.0   1247822.0
# Oregon                  685873.0    691945.0    697293.0    701903.0
# Pennsylvania           2038094.0   2049762.0   2066255.0   2066255.0
_daily_new_tests_timeseries(datetime.now() - timedelta(days=1), ndays=90).rolling(7, min_periods=1).mean()
get_daily_new_tests_timeseries(datetime.now() - timedelta(days=1), ndays=50)
# Out:
# 08-21-2020          0.0
# 08-22-2020     756770.0
# 08-23-2020     622311.0
# 08-24-2020     706704.0
# 08-25-2020     645741.0
# 08-26-2020    1012955.0
# 08-27-2020     751327.0
# 08-28-2020     783052.0
# 08-29-2020     764922.0
# 08-30-2020     740933.0
# 08-31-2020     701070.0
# 09-01-2020     703792.0
# 09-02-2020     649642.0
# 09-03-2020     734770.0
# 09-04-2020     911871.0
# 09-05-2020     805988.0
# 09-06-2020     738604.0
# 09-07-2020     588814.0
# 09-08-2020     537495.0
# 09-09-2020     593993.0
# 09-10-2020     621265.0
# 09-11-2020    2045745.0
# 09-12-2020     821204.0
# 09-13-2020     771355.0
# 09-14-2020     783818.0
# 09-15-2020     383826.0
# 09-16-2020     722895.0
# 09-17-2020     835760.0
# 09-18-2020    1603279.0
# 09-19-2020    1061411.0
# 09-20-2020     896732.0
# 09-21-2020     732721.0
# 09-22-2020     771003.0
# 09-23-2020     846692.0
# 09-24-2020    1021078.0
# 09-25-2020    1002538.0
# 09-26-2020    1008824.0
# 09-27-2020     806069.0
# 09-28-2020    1043622.0
# 09-29-2020     812560.0
# 09-30-2020     783954.0
# 10-01-2020     905751.0
# 10-02-2020    1118277.0
# 10-03-2020     975914.0
# 10-04-2020     934498.0
# 10-05-2020     956383.0
# 10-06-2020     815372.0
# 10-07-2020    1430132.0
# 10-08-2020    1040557.0
# 10-09-2020    1229851.0
# 10-10-2020    1133176.0
# dtype: float64

# %%
dtime = datetime.now() - timedelta(days=1)
col = datetime_to_str(dtime)
get_daily_new_tests_by_state_timeseries(dtime, ndays=1).sort_values(col, axis=0, ascending=False)[col]
# Out:
# Province_State
# California              141948.0
# New York                134579.0
# Texas                    84601.0
# Missouri                 74720.0
# Massachusetts            69324.0
# Illinois                 66256.0
# Ohio                     45895.0
# Michigan                 45293.0
# North Carolina           39530.0
# New Jersey               35033.0
# Minnesota                32497.0
# Arkansas                 26190.0
# Tennessee                24460.0
# Colorado                 22256.0
# Washington               21475.0
# Pennsylvania             21417.0
# Georgia                  19930.0
# Virginia                 18694.0
# South Carolina           17743.0
# Oklahoma                 17168.0
# Wisconsin                14615.0
# Arizona                  12570.0
# Maryland                 12435.0
# Utah                     11846.0
# Indiana                  11203.0
# New Hampshire            10991.0
# Kentucky                 10911.0
# West Virginia            10383.0
# Nebraska                  9965.0
# North Dakota              8158.0
# Alabama                   7868.0
# District of Columbia      6874.0
# Alaska                    6183.0
# New Mexico                6108.0
# Oregon                    5927.0
# Iowa                      5277.0
# Nevada                    4709.0
# Idaho                     4173.0
# Hawaii                    3818.0
# Delaware                  3278.0
# South Dakota              2332.0
# Montana                   1903.0
# Mississippi                957.0
# Vermont                    740.0
# Puerto Rico                472.0
# Guam                       321.0
# Wyoming                    120.0
# Maine                       30.0
# Louisiana                    0.0
# Kansas                       0.0
# Rhode Island                 0.0
# Florida                      0.0
# Connecticut                  0.0
# Name: 10-10-2020, dtype: float64

# %%
def get_hospitalized_data(dtime):
    exclude = [
        'Diamond Princess',
        'Grand Princess',
        'American Samoa',
        'Virgin Islands',
        'Northern Mariana Islands'
    ]
    file = '{0}.csv'.format(datetime_to_str(dtime))
    df = pd.read_csv('csse_covid_19_data/csse_covid_19_daily_reports_us/{0}'.format(file),
                     usecols=['Province_State', 'People_Hospitalized']).fillna(0)
    df = df[~df.Province_State.isin(exclude)] # not isin
    df.rename(columns={ 'People_Hospitalized': datetime_to_str(dtime) }, inplace=True)
    df.set_index(['Province_State'], inplace=True)
    return df

def get_daily_hospitalized_timeseries(dtime, ndays=30):
    df = get_hospitalized_data(dtime)
    for days in range(1, ndays+1):
        df_2 = get_hospitalized_data(dtime - timedelta(days=days))
        df = pd.concat([df_2, df], axis=1, join='inner')
    return df

def get_daily_new_hospitalized_timeseries(dtime, ndays=30):
    df = get_daily_hospitalized_timeseries(dtime, ndays=ndays)
    return df.diff(axis=1).fillna(0).sum(axis=0)

def get_daily_new_hospitalized_by_state_timeseries(dtime, ndays=30):
    df = get_daily_hospitalized_timeseries(dtime, ndays=ndays)
    return df.diff(axis=1).fillna(0)

# %%
# get_daily_hospitalized_timeseries(datetime.now() - timedelta(days=1), ndays=10)

# %%
# get_daily_new_hospitalized_timeseries(datetime.now() - timedelta(days=1), ndays=30)

# %%
# get_daily_new_hospitalized_by_state_timeseries(datetime.now() - timedelta(days=1), ndays=10)

# %%
# dtime = datetime.now() - timedelta(days=1)
# col = datetime_to_str(dtime)
# get_daily_new_hospitalized_by_state_timeseries(dtime, ndays=14).sort_values(col, axis=0, ascending=False)[col]

# %%
def get_daily_data(dtime, col):
    exclude = [
        'Diamond Princess',
        'Grand Princess',
        'American Samoa',
        'Virgin Islands',
        'Northern Mariana Islands',
        'Puerto Rico',
    ]
    file = '{0}.csv'.format(datetime_to_str(dtime))
    df = pd.read_csv('csse_covid_19_data/csse_covid_19_daily_reports_us/{0}'.format(file),
                     usecols=['Province_State', col]).fillna(0)
    df = df[~df.Province_State.isin(exclude)] # not isin
    df.set_index(['Province_State'], inplace=True)
    return df

def get_daily_confirmed(dtime):
    conf_curr = get_daily_data(dtime, 'Confirmed')
    conf_prev = get_daily_data(dtime - timedelta(days=1), 'Confirmed')
    conf = (conf_curr - conf_prev)
    conf.rename(columns={'Confirmed': datetime_to_str(dtime)}, inplace=True)
    return conf

def get_daily_tested(dtime, lag=0):
    tstd_curr = get_daily_data(dtime - timedelta(days=lag), 'People_Tested')
    tstd_prev = get_daily_data(dtime - timedelta(days=lag+1), 'People_Tested')
    tstd = (tstd_curr - tstd_prev)
    tstd.rename(columns={'People_Tested': datetime_to_str(dtime)}, inplace=True)
    return tstd

def get_confirmed_timeseries(dtime, ndays=10):
    df = get_daily_confirmed(dtime)
    for days in range(1, ndays+1):
        df_2 = get_daily_confirmed(dtime - timedelta(days=days))
        df = pd.concat([df_2, df], axis=1, join='inner')
    return df.rolling(7, axis=1, min_periods=1).mean()

def get_tested_timeseries(dtime, lag=0, ndays=10):
    df = get_daily_tested(dtime, lag=lag)
    for days in range(1, ndays+1):
        df_2 = get_daily_tested(dtime - timedelta(days=days), lag=lag)
        df = pd.concat([df_2, df], axis=1, join='inner')
    return df.rolling(7, axis=1, min_periods=1).mean()
    
def get_pct_plus(dtime, ndays=10, lag=0):
    conf = get_confirmed_timeseries(dtime, ndays=ndays)
    tstd = get_tested_timeseries(dtime, ndays=ndays)
    return 100 * conf / tstd

# get_daily_confirmed(datetime.now() - timedelta(days=2))
# get_daily_tested(datetime.now() - timedelta(days=2))
# get_confirmed_timeseries(datetime.now() - timedelta(days=2))
# get_tested_timeseries(datetime.now() - timedelta(days=2))
# get_pct_plus(datetime.now() - timedelta(days=2), lag=1)
# get_pct_plus(datetime.now() - timedelta(days=2), lag=2)
# get_pct_plus(datetime.now() - timedelta(days=2), lag